# %% [markdown]
# # Problem 1: Cryptocurrency Token Data
# This data structure represents information about different cryptocurrency tokens listed on a decentralized exchange (DEX).

# %%
repr
crypto_tokens = [
    {
        "name": "Token A",
        "symbol": "TKA",
        "blockchain": "Ethereum",
        "current_price_usd": 100.0,
        "transaction_history": [
            {
                "date": "2024-01-10",
                "prices": {
                    "open": 98.0,
                    "close": 100.0,
                    "high": 101.0,
                    "low": 97.0
                },
                "volume": 12000
            },
            {
                "date": "2024-01-09",
                "prices": {
                    "open": 97.0,
                    "close": 98.0,
                    "high": 99.0,
                    "low": 96.0
                },
                "volume": 15000
            }
        ],
        "supported_chains": ["Ethereum", "Polygon"]
    },
    {
        "name": "Token B",
        "symbol": "TKB",
        "blockchain": "Binance Smart Chain",
        "current_price_usd": 200.0,
        "transaction_history": [
            {
                "date": "2024-01-10",
                "prices": {
                    "open": 198.0,
                    "close": 200.0,
                    "high": 202.0,
                    "low": 196.0
                },
                "volume": 18000
            },
            {
                "date": "2024-01-09",
                "prices": {
                    "open": 196.0,
                    "close": 198.0,
                    "high": 199.0,
                    "low": 195.0
                },
                "volume": 17000
            }
        ],
        "supported_chains": ["Binance Smart Chain", "Avalanche"]
    },
    {
        "name": "Token C",
        "symbol": "TKC",
        "blockchain": "Solana",
        "current_price_usd": 300.0,
        "transaction_history": [
            {
                "date": "2024-01-10",
                "prices": {
                    "open": 295.0,
                    "close": 300.0,
                    "high": 302.0,
                    "low": 294.0
                },
                "volume": 22000
            },
            {
                "date": "2024-01-09",
                "prices": {
                    "open": 294.0,
                    "close": 295.0,
                    "high": 296.0,
                    "low": 293.0
                },
                "volume": 21000
            }
        ],
        "supported_chains": ["Solana", "Fantom"]
    }
]
repr
# Out:
# <function repr(obj, /)>

# %%
# Q1  Display the current price of "Token B".

print(crypto_tokens[1]["current_price_usd"])
# Out:
# 200.0

# %%
#  Q2 Add a new token "Token D" with some initial data to the `crypto_tokens` list.

crypto_tokens.append({
    "name": "TokenD",
    "symbol": "TKD",
    "blockchain": "Arbitrum",
    "current_price_usd": 40.5,
    "transaction_history": [
        {
            "date": "2025-07-09",
            "prices": {
                "open": 38.7,
                "close": 38.0,
                "high": 40.0,
                "low": 38.5
            },
            "volume": 14000
        },
        {
            "date": "2025-07-10",
            "prices": {
                "open": 39.5,
                "close": 40.5,
                "high": 41.0,
                "low": 39.0
            },
            "volume": 15360
        }
    ],
    "supported_chains": ["Avalanche", "Algorand"]
})
crypto_tokens
# Out:
# [{'name': 'Token A',
#   'symbol': 'TKA',
#   'blockchain': 'Ethereum',
#   'current_price_usd': 100.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 98.0, 'close': 100.0, 'high': 101.0, 'low': 97.0},
#     'volume': 12000},
#    {'date': '2024-01-09',
#     'prices': {'open': 97.0, 'close': 98.0, 'high': 99.0, 'low': 96.0},
#     'volume': 15000}],
#   'supported_chains': ['Ethereum', 'Polygon']},
#  {'name': 'Token B',
#   'symbol': 'TKB',
#   'blockchain': 'Binance Smart Chain',
#   'current_price_usd': 200.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 198.0, 'close': 200.0, 'high': 202.0, 'low': 196.0},
#     'volume': 18000},
#    {'date': '2024-01-09',
#     'prices': {'open': 196.0, 'close': 198.0, 'high': 199.0, 'low': 195.0},
#     'volume': 17000}],
#   'supported_chains': ['Binance Smart Chain', 'Avalanche']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 300.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}],
#   'supported_chains': ['Solana', 'Fantom']},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 400.0,
#   'date': '2025-07-10',
#   'prices': {'open': 395.0, 'close': 400.0, 'high': 405.0, 'low': 390.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'date': '2025-07-10',
#   'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'transaction_history': [{'date': '2025-07-09',
#     'prices': {'open': 38.7, 'close': 38.0, 'high': 40.0, 'low': 38.5},
#     'volume': 14000},
#    {'date': '2025-07-10',
#     'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0},
#     'volume': 15360}],
#   'supported_chains': ['Avalanche', 'Algorand']}]

# %%
# Q3 Update the current price of "Token C" to 310.0.

crypto_tokens[2].update({"current_price_usd": 310.0})
crypto_tokens
# Out:
# [{'name': 'Token A',
#   'symbol': 'TKA',
#   'blockchain': 'Ethereum',
#   'current_price_usd': 100.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 98.0, 'close': 100.0, 'high': 101.0, 'low': 97.0},
#     'volume': 12000},
#    {'date': '2024-01-09',
#     'prices': {'open': 97.0, 'close': 98.0, 'high': 99.0, 'low': 96.0},
#     'volume': 15000}],
#   'supported_chains': ['Ethereum', 'Polygon']},
#  {'name': 'Token B',
#   'symbol': 'TKB',
#   'blockchain': 'Binance Smart Chain',
#   'current_price_usd': 200.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 198.0, 'close': 200.0, 'high': 202.0, 'low': 196.0},
#     'volume': 18000},
#    {'date': '2024-01-09',
#     'prices': {'open': 196.0, 'close': 198.0, 'high': 199.0, 'low': 195.0},
#     'volume': 17000}],
#   'supported_chains': ['Binance Smart Chain', 'Avalanche']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 310.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}],
#   'supported_chains': ['Solana', 'Fantom']},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 400.0,
#   'date': '2025-07-10',
#   'prices': {'open': 395.0, 'close': 400.0, 'high': 405.0, 'low': 390.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'date': '2025-07-10',
#   'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'transaction_history': [{'date': '2025-07-09',
#     'prices': {'open': 38.7, 'close': 38.0, 'high': 40.0, 'low': 38.5},
#     'volume': 14000},
#    {'date': '2025-07-10',
#     'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0},
#     'volume': 15360}],
#   'supported_chains': ['Avalanche', 'Algorand']}]

# %%
# Q4 Remove the transaction history for "Token A" on "2024-01-09".

crypto_tokens[0]['transaction_history'].pop(0)
crypto_tokens
#crypto_tokens[0].keys()
# Out:
# [{'name': 'Token A',
#   'symbol': 'TKA',
#   'blockchain': 'Ethereum',
#   'current_price_usd': 100.0,
#   'transaction_history': [{'date': '2024-01-09',
#     'prices': {'open': 97.0, 'close': 98.0, 'high': 99.0, 'low': 96.0},
#     'volume': 15000}],
#   'supported_chains': ['Ethereum', 'Polygon']},
#  {'name': 'Token B',
#   'symbol': 'TKB',
#   'blockchain': 'Binance Smart Chain',
#   'current_price_usd': 200.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 198.0, 'close': 200.0, 'high': 202.0, 'low': 196.0},
#     'volume': 18000},
#    {'date': '2024-01-09',
#     'prices': {'open': 196.0, 'close': 198.0, 'high': 199.0, 'low': 195.0},
#     'volume': 17000}],
#   'supported_chains': ['Binance Smart Chain', 'Avalanche']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 310.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}],
#   'supported_chains': ['Solana', 'Fantom']},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 400.0,
#   'date': '2025-07-10',
#   'prices': {'open': 395.0, 'close': 400.0, 'high': 405.0, 'low': 390.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'date': '2025-07-10',
#   'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'transaction_history': [{'date': '2025-07-09',
#     'prices': {'open': 38.7, 'close': 38.0, 'high': 40.0, 'low': 38.5},
#     'volume': 14000},
#    {'date': '2025-07-10',
#     'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0},
#     'volume': 15360}],
#   'supported_chains': ['Avalanche', 'Algorand']}]

# %%
# Q5 Display the closing price of "Token B" on "2024-01-10"

print(crypto_tokens[1]['transaction_history'][0]['prices']['close'])
# Out:
# 200.0

# %%
# Q6 Change the opening price of "Token A" on "2024-01-10" to 99.0.

crypto_tokens[0]['transaction_history'][0]['prices'].update({'open': 99.0})
crypto_tokens
# Out:
# [{'name': 'Token A',
#   'symbol': 'TKA',
#   'blockchain': 'Ethereum',
#   'current_price_usd': 100.0,
#   'transaction_history': [{'date': '2024-01-09',
#     'prices': {'open': 99.0, 'close': 98.0, 'high': 99.0, 'low': 96.0},
#     'volume': 15000}],
#   'supported_chains': ['Ethereum', 'Polygon']},
#  {'name': 'Token B',
#   'symbol': 'TKB',
#   'blockchain': 'Binance Smart Chain',
#   'current_price_usd': 200.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 198.0, 'close': 200.0, 'high': 202.0, 'low': 196.0},
#     'volume': 18000},
#    {'date': '2024-01-09',
#     'prices': {'open': 196.0, 'close': 198.0, 'high': 199.0, 'low': 195.0},
#     'volume': 17000}],
#   'supported_chains': ['Binance Smart Chain', 'Avalanche']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 310.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}],
#   'supported_chains': ['Solana', 'Fantom']},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 400.0,
#   'date': '2025-07-10',
#   'prices': {'open': 395.0, 'close': 400.0, 'high': 405.0, 'low': 390.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'date': '2025-07-10',
#   'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'transaction_history': [{'date': '2025-07-09',
#     'prices': {'open': 38.7, 'close': 38.0, 'high': 40.0, 'low': 38.5},
#     'volume': 14000},
#    {'date': '2025-07-10',
#     'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0},
#     'volume': 15360}],
#   'supported_chains': ['Avalanche', 'Algorand']}]

# %%
# Q7 Add a new transaction history entry for "Token C" on "2024-01-11".

crypto_tokens.append({
    "name": "Token C",
    "symbol": "TKC",
    "blockchain": "Solana",
    "current_price_usd": 300.0,
    "transaction_history":[
        {
            "date": "2024-01-11",
            "prices":{
                "open": 290.0,
                "close": 296.0,
                "high": 299.0,
                "low":  288.5
            },
            "volume": 23000
        },
        {
            "date": "2024-01-10",
            "prices":{
                "open": 295.0,
                "close": 300.0,
                "high": 302.0,
                "low":  294.0
            },
            "volume": 22000
        },
        {
            "date": "2024-01-09",
            "prices":{
                "open": 294.0,
                "close": 295.0,
                "high": 296.0,
                "low":  293.0
            },
            "volume": 21000
        }
    ]
})
crypto_tokens
# Out:
# [{'name': 'Token A',
#   'symbol': 'TKA',
#   'blockchain': 'Ethereum',
#   'current_price_usd': 100.0,
#   'transaction_history': [{'date': '2024-01-09',
#     'prices': {'open': 99.0, 'close': 98.0, 'high': 99.0, 'low': 96.0},
#     'volume': 15000}],
#   'supported_chains': ['Ethereum', 'Polygon']},
#  {'name': 'Token B',
#   'symbol': 'TKB',
#   'blockchain': 'Binance Smart Chain',
#   'current_price_usd': 200.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 198.0, 'close': 200.0, 'high': 202.0, 'low': 196.0},
#     'volume': 18000},
#    {'date': '2024-01-09',
#     'prices': {'open': 196.0, 'close': 198.0, 'high': 199.0, 'low': 195.0},
#     'volume': 17000}],
#   'supported_chains': ['Binance Smart Chain', 'Avalanche']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 310.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}],
#   'supported_chains': ['Solana', 'Fantom']},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 400.0,
#   'date': '2025-07-10',
#   'prices': {'open': 395.0, 'close': 400.0, 'high': 405.0, 'low': 390.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'date': '2025-07-10',
#   'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'transaction_history': [{'date': '2025-07-09',
#     'prices': {'open': 38.7, 'close': 38.0, 'high': 40.0, 'low': 38.5},
#     'volume': 14000},
#    {'date': '2025-07-10',
#     'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0},
#     'volume': 15360}],
#   'supported_chains': ['Avalanche', 'Algorand']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 300.0,
#   'transaction_history': [{'date': '2024-01-11',
#     'prices': {'open': 290.0, 'close': 296.0, 'high': 299.0, 'low': 288.5},
#     'volume': 23000},
#    {'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}]}]

# %%
# Q8  Remove "Avalanche" from the supported chains of "Token B".

crypto_tokens[1]['supported_chains'] = ['Binance Smart Chain', 'Avalanche']
crypto_tokens[1]['supported_chains'].pop(1)
crypto_tokens
# Out:
# [{'name': 'Token A',
#   'symbol': 'TKA',
#   'blockchain': 'Ethereum',
#   'current_price_usd': 100.0,
#   'transaction_history': [{'date': '2024-01-09',
#     'prices': {'open': 99.0, 'close': 98.0, 'high': 99.0, 'low': 96.0},
#     'volume': 15000}],
#   'supported_chains': ['Ethereum', 'Polygon']},
#  {'name': 'Token B',
#   'symbol': 'TKB',
#   'blockchain': 'Binance Smart Chain',
#   'current_price_usd': 200.0,
#   'transaction_history': [],
#   'supported_chains': ['Binance Smart Chain']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 310.0,
#   'transaction_history': [{'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}],
#   'supported_chains': ['Solana', 'Fantom']},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 400.0,
#   'date': '2025-07-10',
#   'prices': {'open': 395.0, 'close': 400.0, 'high': 405.0, 'low': 390.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'date': '2025-07-10',
#   'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0}},
#  {'name': 'TokenD',
#   'symbol': 'TKD',
#   'blockchain': 'Arbitrum',
#   'current_price_usd': 40.5,
#   'transaction_history': [{'date': '2025-07-09',
#     'prices': {'open': 38.7, 'close': 38.0, 'high': 40.0, 'low': 38.5},
#     'volume': 14000},
#    {'date': '2025-07-10',
#     'prices': {'open': 39.5, 'close': 40.5, 'high': 41.0, 'low': 39.0},
#     'volume': 15360}],
#   'supported_chains': ['Avalanche', 'Algorand']},
#  {'name': 'Token C',
#   'symbol': 'TKC',
#   'blockchain': 'Solana',
#   'current_price_usd': 300.0,
#   'transaction_history': [{'date': '2024-01-11',
#     'prices': {'open': 290.0, 'close': 296.0, 'high': 299.0, 'low': 288.5},
#     'volume': 23000},
#    {'date': '2024-01-10',
#     'prices': {'open': 295.0, 'close': 300.0, 'high': 302.0, 'low': 294.0},
#     'volume': 22000},
#    {'date': '2024-01-09',
#     'prices': {'open': 294.0, 'close': 295.0, 'high': 296.0, 'low': 293.0},
#     'volume': 21000}]}]
